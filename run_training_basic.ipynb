# %%
from train_basic import *
import os
import shutil
import models
from timm.models import create_model
from models.modules.mobileone import reparameterize_model
import torch
import torch.nn as nn
import torchvision
from dataset_basic import get_transforms, load_data, get_data_loaders
from label_smooth import LabelSmoothingCrossEntropy
import models
# import torch.nn as nn
# from AdamW import AdamW
# from onecycle import OneCycleLR

#path = './透明_by_CCD/1站'
#path = '大峰2034-07-19-NG/透明'
path = '1020_NG_膠囊_by_CCD/CCD1'
#path = 'CCD2_original_combine_foreground_in_right__rotate90_and-90'
#path = 'CCD1_original_combine_foreground_in_right__rotate90_and-90'
#path = './AAA123/CCD8/Part'
#path = './透明_combine'

##################### to reomove .ipynb_checkpoints #################
# Set the path to the folder
#folder_path = './AAA123/CCD8/Part'
#folder_path = './透明_combine'
#folder_path = './透明_by_CCD/1站'
folder_path = '1020_NG_膠囊_by_CCD/CCD1'
#folder_path = 'CCD1_original_combine_foreground_in_right__rotate90_and-90'

# Checkpoint folder name
checkpoint_folder = '.ipynb_checkpoints'

# Full path to the checkpoint folder
checkpoint_path = os.path.join(folder_path, checkpoint_folder)

# Remove the folder
if os.path.exists(checkpoint_path):
    shutil.rmtree(checkpoint_path)
    print(f"Removed {checkpoint_path}")
else:
    print(f"{checkpoint_path} does not exist")

######################## END #######################################
    
bs = 16  # Batch size

transformer = get_transforms()
train, val, test, original = load_data(path, transformer)
loaders = get_data_loaders(train, val, test, bs)

dataset_sizes = {
    'train': len(train),
    'val': len(val),
    'test': len(test),
}
num_epochs = 100

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# # Initialize model
# mobilenet_v3_large = torchvision.models.mobilenet_v3_large(pretrained=True)

# for param in mobilenet_v3_large.parameters():
#     param.requires_grad = False

# Replace the last layer in the classifier
# in_features = mobilenet_v3_large.classifier[-1].in_features
# out_features = len(original.classes) # original should come from dataset.py
# mobilenet_v3_large.classifier[-1] = nn.Linear(in_features=in_features, out_features=out_features, bias=True)

################################MogaNet####################################################################
# num_classes_original = len(original.classes)
# model = models.moganet_xtiny(pretrained=True)
# model_ft = model.to(device)
# # Set the device
# model_ft.head = nn.Linear(in_features=model.head.in_features, out_features=num_classes_original, bias=True)

#############################MogaNet#######################################################################

############################# ml-fasttvit #################################################################
num_classes_original = len(original.classes)
model = create_model("fastvit_t8")
# Load unfused pre-trained checkpoint for fine-tuning
# or for downstream task training like detection/segmentation
checkpoint = torch.load('fastvit_t8.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
#model.load_state_dict(checkpoint)
model_ft = model.to(device)
model_ft.head = nn.Linear(in_features=model.head.in_features, out_features=num_classes_original, bias=True)
#model_ft.linear = nn.Linear(in_features=model.linear.in_features, out_features=num_classes_original, bias=True)


######################### ml-fastvit by another way ###########################################################
# # Assuming other necessary imports are already done
# from models import fastvit_t8  # Import the model

# # Initialize the model
# model = fastvit_t8(pretrained=False)
# model.to(device)

# # Adapt the final layer if necessary (assuming a classification task)
# num_classes_original = len(original.classes)
# model.head = nn.Linear(in_features=model.head.in_features, out_features=num_classes_original, bias=True)

# # Load pretrained weights if available
# # Make sure the format of your checkpoint matches what the model expects
# checkpoint_path = 'fastvit_t8.pth.tar'
# #checkpoint = torch.load(checkpoint_path, map_location='cpu')
# checkpoint = torch.load(checkpoint_path)
# if 'state_dict' in checkpoint:
#     model.load_state_dict(checkpoint['state_dict'])
# else:
#     model.load_state_dict(checkpoint)

# Proceed with the rest of your code for training, validation, etc.



########################### END ##########################################################################



# for param in mobilenet_v3_large.parameters():
#     param.requires_grad = False

#model_ft = mobilenet_v3_large.to(device)

# Loss function
#criterion = nn.CrossEntropyLoss()
criterion = LabelSmoothingCrossEntropy(reduction='sum')

# Optimizer
optimizer_ft = AdamW(model_ft.parameters(), lr=2.31E-03, betas=(0.9, 0.99), weight_decay=0.01, amsgrad=False)
#optimizer_ft = AdamW(model_ft.parameters(), lr=6.19E-03, betas=(0.9, 0.99), weight_decay=0.01, amsgrad=False) # dataset1~dataset5

# Scheduler
exp_lr_scheduler = OneCycleLR(optimizer_ft, lr_range=(1.0E-04, 1.0E-02), num_steps=int(len(loaders['train'])*num_epochs/len(loaders['train'])))

# Train the model
train_loss_result, val_loss_result, train_acc_result, val_acc_result, lr_oneCycle, model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, loaders, dataset_sizes, num_epochs=num_epochs, device=device)

torch.save(model_ft.state_dict(), './save_model/fastvit_t8_freeze_CCD1_without_augmentation_1219.pt')
# Out:
# If for semantic segmentation, please install mmsegmentation first
# If for detection, please install mmdetection first
# 1020_NG_膠囊_by_CCD/CCD1/.ipynb_checkpoints does not exist
# Epoch 0/99
# ----------
# train Loss: 35.3511 Acc: 0.2306
# val Loss: 35.0165 Acc: 0.2500
#
# Epoch 1/99
# ----------
# train Loss: 25.8188 Acc: 0.5862
# val Loss: 34.2010 Acc: 0.2500
#
# Epoch 2/99
# ----------
# train Loss: 20.4152 Acc: 0.6789
# val Loss: 48.1556 Acc: 0.0769
#
# Epoch 3/99
# ----------
# train Loss: 18.3652 Acc: 0.7047
# val Loss: 44.8221 Acc: 0.1731
#
# Epoch 4/99
# ----------
# train Loss: 18.1727 Acc: 0.7177
# val Loss: 42.8592 Acc: 0.2500
#
# Epoch 5/99
# ----------
# train Loss: 16.7098 Acc: 0.7845
# val Loss: 51.2227 Acc: 0.1346
#
# Epoch 6/99
# ----------
# train Loss: 18.8825 Acc: 0.7134
# val Loss: 55.6461 Acc: 0.3077
#
# Epoch 7/99
# ----------
# train Loss: 17.2654 Acc: 0.7672
# val Loss: 47.2846 Acc: 0.2115
#
# Epoch 8/99
# ----------
# train Loss: 15.9081 Acc: 0.7953
# val Loss: 47.7622 Acc: 0.1154
#
# Epoch 9/99
# ----------
# train Loss: 17.1898 Acc: 0.7651
# val Loss: 56.4224 Acc: 0.1923
#
# Epoch 10/99
# ----------
# train Loss: 17.6151 Acc: 0.7478
# val Loss: 71.8574 Acc: 0.0962
#
# Epoch 11/99
# ----------
# train Loss: 17.2218 Acc: 0.7586
# val Loss: 152.0600 Acc: 0.1346
#
# Epoch 12/99
# ----------
# train Loss: 16.4319 Acc: 0.7953
# val Loss: 85.4921 Acc: 0.1538
#
# Epoch 13/99
# ----------
# train Loss: 16.0784 Acc: 0.7953
# val Loss: 36.1185 Acc: 0.4423
#
# Epoch 14/99
# ----------
# train Loss: 15.6625 Acc: 0.8082
# val Loss: 53.6619 Acc: 0.2692
#
# Epoch 15/99
# ----------
# train Loss: 17.2011 Acc: 0.7522
# val Loss: 50.5558 Acc: 0.2115
#
# Epoch 16/99
# ----------
# train Loss: 16.9723 Acc: 0.7672
# val Loss: 57.6533 Acc: 0.2308
#
# Epoch 17/99
# ----------
# train Loss: 15.6187 Acc: 0.7931
# val Loss: 64.2101 Acc: 0.2500
#
# Epoch 18/99
# ----------
# train Loss: 15.2357 Acc: 0.8384
# val Loss: 53.6827 Acc: 0.1154
#
# Epoch 19/99
# ----------
# train Loss: 15.8181 Acc: 0.8039
# val Loss: 76.2530 Acc: 0.0962
#
# Epoch 20/99
# ----------
# train Loss: 15.2249 Acc: 0.8190
# val Loss: 69.5765 Acc: 0.0577
#
# Epoch 21/99
# ----------
# train Loss: 14.7376 Acc: 0.8254
# val Loss: 40.4946 Acc: 0.2115
#
# Epoch 22/99
# ----------
# train Loss: 14.9684 Acc: 0.8297
# val Loss: 62.3127 Acc: 0.1154
#
# Epoch 23/99
# ----------
# train Loss: 14.4276 Acc: 0.8448
# val Loss: 67.5304 Acc: 0.1923
#
# Epoch 24/99
# ----------
# train Loss: 14.1220 Acc: 0.8556
# val Loss: 89.9093 Acc: 0.0962
#
# Epoch 25/99
# ----------
# train Loss: 17.3557 Acc: 0.7759
# val Loss: 2295.5321 Acc: 0.1346
#
# Epoch 26/99
# ----------
# train Loss: 14.1619 Acc: 0.8362
# val Loss: 93.2334 Acc: 0.0962
#
# Epoch 27/99
# ----------
# train Loss: 13.7120 Acc: 0.8728
# val Loss: 68.5880 Acc: 0.0769
#
# Epoch 28/99
# ----------
# train Loss: 12.5837 Acc: 0.8901
# val Loss: 91.8799 Acc: 0.0962
#
# Epoch 29/99
# ----------
# train Loss: 12.1540 Acc: 0.8966
# val Loss: 92.5732 Acc: 0.0577
#
# Epoch 30/99
# ----------
# train Loss: 12.8270 Acc: 0.8901
# val Loss: 632.0757 Acc: 0.2115
#
# Epoch 31/99
# ----------
# train Loss: 13.2788 Acc: 0.8858
# val Loss: 58.6828 Acc: 0.1731
#
# Epoch 32/99
# ----------
# train Loss: 11.8504 Acc: 0.9138
# val Loss: 73.0098 Acc: 0.1346
#
# Epoch 33/99
# ----------
# train Loss: 12.2571 Acc: 0.9116
# val Loss: 94.0936 Acc: 0.1538
#
# Epoch 34/99
# ----------
# train Loss: 14.6853 Acc: 0.8233
# val Loss: 64.2264 Acc: 0.1346
#
# Epoch 35/99
# ----------
# train Loss: 15.1399 Acc: 0.8384
# val Loss: 41.2383 Acc: 0.3077
#
# Epoch 36/99
# ----------
# train Loss: 12.1848 Acc: 0.9052
# val Loss: 52.9863 Acc: 0.0962
#
# Epoch 37/99
# ----------
# train Loss: 10.9648 Acc: 0.9375
# val Loss: 41.7656 Acc: 0.3077
#
# Epoch 38/99
# ----------
# train Loss: 12.3657 Acc: 0.9095
# val Loss: 63.1364 Acc: 0.1154
#
# Epoch 39/99
# ----------
# train Loss: 11.3652 Acc: 0.9418
# val Loss: 46.3861 Acc: 0.1346
#
# Epoch 40/99
# ----------
# train Loss: 10.5187 Acc: 0.9547
# val Loss: 67.0501 Acc: 0.0962
#
# Epoch 41/99
# ----------
# train Loss: 10.6231 Acc: 0.9504
# val Loss: 51.2226 Acc: 0.0385
#
# Epoch 42/99
# ----------
# train Loss: 13.9270 Acc: 0.8707
# val Loss: 60.4122 Acc: 0.2500
#
# Epoch 43/99
# ----------
# train Loss: 12.7359 Acc: 0.8966
# val Loss: 56.0984 Acc: 0.3269
#
# Epoch 44/99
# ----------
# train Loss: 12.6289 Acc: 0.9116
# val Loss: 87.0668 Acc: 0.0769
#
# Epoch 45/99
# ----------
# train Loss: 12.0298 Acc: 0.9073
# val Loss: 58.1410 Acc: 0.1923
#
# Epoch 46/99
# ----------
# train Loss: 11.9555 Acc: 0.9310
# val Loss: 56.7544 Acc: 0.2692
#
# Epoch 47/99
# ----------
# train Loss: 10.7129 Acc: 0.9569
# val Loss: 52.0852 Acc: 0.3462
#
# Epoch 48/99
# ----------
# train Loss: 11.2982 Acc: 0.9375
# val Loss: 74.2633 Acc: 0.1154
#
# Epoch 49/99
# ----------
# train Loss: 11.2715 Acc: 0.9418
# val Loss: 43.5182 Acc: 0.3077
#
# Epoch 50/99
# ----------
# train Loss: 10.4696 Acc: 0.9677
# val Loss: 82.1549 Acc: 0.1923
#
# Epoch 51/99
# ----------
# train Loss: 9.7210 Acc: 0.9828
# val Loss: 56.8886 Acc: 0.0962
#
# Epoch 52/99
# ----------
# train Loss: 9.4600 Acc: 0.9871
# val Loss: 348.9370 Acc: 0.1538
#
# Epoch 53/99
# ----------
# train Loss: 9.6930 Acc: 0.9806
# val Loss: 50.6543 Acc: 0.0962
#
# Epoch 54/99
# ----------
# train Loss: 9.1086 Acc: 0.9978
# val Loss: 31.8273 Acc: 0.4423
#
# Epoch 55/99
# ----------
# train Loss: 8.8469 Acc: 0.9978
# val Loss: 29.8043 Acc: 0.5769
#
# Epoch 56/99
# ----------
# train Loss: 8.6555 Acc: 0.9978
# val Loss: 19.7695 Acc: 0.7692
#
# Epoch 57/99
# ----------
# train Loss: 8.4780 Acc: 1.0000
# val Loss: 35.1613 Acc: 0.6538
#
# Epoch 58/99
# ----------
# train Loss: 8.4029 Acc: 1.0000
# val Loss: 26.6645 Acc: 0.6154
#
# Epoch 59/99
# ----------
# train Loss: 8.3719 Acc: 1.0000
# val Loss: 19.0034 Acc: 0.6923
#
# Epoch 60/99
# ----------
# train Loss: 8.3524 Acc: 1.0000
# val Loss: 19.8858 Acc: 0.6923
#
# Epoch 61/99
# ----------
# train Loss: 8.3332 Acc: 1.0000
# val Loss: 19.5498 Acc: 0.7115
#
# Epoch 62/99
# ----------
# train Loss: 8.3012 Acc: 1.0000
# val Loss: 18.8821 Acc: 0.7308
#
# Epoch 63/99
# ----------
# train Loss: 8.3161 Acc: 1.0000
# val Loss: 18.6797 Acc: 0.6731
#
# Epoch 64/99
# ----------
# train Loss: 8.3250 Acc: 1.0000
# val Loss: 68.2803 Acc: 0.3269
#
# Epoch 65/99
# ----------
# train Loss: 8.3384 Acc: 1.0000
# val Loss: 49.4658 Acc: 0.6154
#
# Epoch 66/99
# ----------
# train Loss: 8.3859 Acc: 1.0000
# val Loss: 39.2356 Acc: 0.3269
#
# Epoch 67/99
# ----------
# train Loss: 10.0968 Acc: 0.9591
# val Loss: 96.5936 Acc: 0.0192
#
# Epoch 68/99
# ----------
# train Loss: 11.2098 Acc: 0.9267
# val Loss: 53.9519 Acc: 0.2115
#
# Epoch 69/99
# ----------
# train Loss: 9.9804 Acc: 0.9655
# val Loss: 587.4900 Acc: 0.1346
#
# Epoch 70/99
# ----------
# train Loss: 8.9905 Acc: 0.9935
# val Loss: 36.7878 Acc: 0.5577
#
# Epoch 71/99
# ----------
# train Loss: 8.5567 Acc: 0.9978
# val Loss: 27.8585 Acc: 0.6731
#
# Epoch 72/99
# ----------
# train Loss: 8.4209 Acc: 1.0000
# val Loss: 16.6477 Acc: 0.7885
#
# Epoch 73/99
# ----------
# train Loss: 8.3598 Acc: 1.0000
# val Loss: 16.4905 Acc: 0.7308
#
# Epoch 74/99
# ----------
# train Loss: 8.3163 Acc: 1.0000
# val Loss: 17.1617 Acc: 0.7885
#
# Epoch 75/99
# ----------
# train Loss: 8.2964 Acc: 1.0000
# val Loss: 16.0599 Acc: 0.7500
#
# Epoch 76/99
# ----------
# train Loss: 8.2849 Acc: 1.0000
# val Loss: 22.7565 Acc: 0.5962
#
# Epoch 77/99
# ----------
# train Loss: 8.2764 Acc: 1.0000
# val Loss: 25.6384 Acc: 0.5769
#
# Epoch 78/99
# ----------
# train Loss: 8.2690 Acc: 1.0000
# val Loss: 19.2674 Acc: 0.7115
#
# Epoch 79/99
# ----------
# train Loss: 8.2620 Acc: 1.0000
# val Loss: 16.8886 Acc: 0.7692
#
# Epoch 80/99
# ----------
# train Loss: 8.2566 Acc: 1.0000
# val Loss: 20.0146 Acc: 0.6923
#
# Epoch 81/99
# ----------
# train Loss: 8.2529 Acc: 1.0000
# val Loss: 16.0324 Acc: 0.7692
#
# Epoch 82/99
# ----------
# train Loss: 8.2503 Acc: 1.0000
# val Loss: 15.9092 Acc: 0.7500
#
# Epoch 83/99
# ----------
# train Loss: 8.2485 Acc: 1.0000
# val Loss: 15.8532 Acc: 0.7500
#
# Epoch 84/99
# ----------
# train Loss: 8.2469 Acc: 1.0000
# val Loss: 16.6049 Acc: 0.7885
#
# Epoch 85/99
# ----------
# train Loss: 8.2442 Acc: 1.0000
# val Loss: 18.8364 Acc: 0.7692
#
# Epoch 86/99
# ----------
# train Loss: 8.2429 Acc: 1.0000
# val Loss: 25.1065 Acc: 0.5769
#
# Epoch 87/99
# ----------
# train Loss: 8.2433 Acc: 1.0000
# val Loss: 20.2391 Acc: 0.7115
#
# Epoch 88/99
# ----------
# train Loss: 8.2403 Acc: 1.0000
# val Loss: 17.9001 Acc: 0.7885
#
# Epoch 89/99
# ----------
# train Loss: 8.2391 Acc: 1.0000
# val Loss: 17.4170 Acc: 0.7885
#
# Epoch 90/99
# ----------
# train Loss: 8.2360 Acc: 1.0000
# val Loss: 16.9107 Acc: 0.7885
#
# Epoch 91/99
# ----------
# train Loss: 8.2353 Acc: 1.0000
# val Loss: 17.0196 Acc: 0.7885
#
# Epoch 92/99
# ----------
# train Loss: 8.2351 Acc: 1.0000
# val Loss: 16.9897 Acc: 0.7885
#
# Epoch 93/99
# ----------
# train Loss: 8.2348 Acc: 1.0000
# val Loss: 17.0112 Acc: 0.7885
#
# Epoch 94/99
# ----------
# train Loss: 8.2347 Acc: 1.0000
# val Loss: 17.0079 Acc: 0.7885
#
# Epoch 95/99
# ----------
# train Loss: 8.2345 Acc: 1.0000
# val Loss: 17.0172 Acc: 0.7885
#
# Epoch 96/99
# ----------
# train Loss: 8.2343 Acc: 1.0000
# val Loss: 17.0120 Acc: 0.7885
#
# Epoch 97/99
# ----------
# train Loss: 8.2342 Acc: 1.0000
# val Loss: 17.0148 Acc: 0.7885
#
# Epoch 98/99
# ----------
# train Loss: 8.2341 Acc: 1.0000
# val Loss: 17.0161 Acc: 0.7885
#
# Epoch 99/99
# ----------
# train Loss: 8.2340 Acc: 1.0000
# val Loss: 17.0097 Acc: 0.7885
#
# Training complete in 5m 6s
# Best val Acc: 0.788462
# training finish !

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 5))
plt.plot(train_loss_result,label='train loss')
plt.plot(val_loss_result, label='val loss')
plt.legend()
plt.xlim(0,num_epochs)
plt.xlabel('Epochs')

plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize = (8, 5))
plt.plot(train_acc_result,label='train acc')
plt.plot(val_acc_result, label='val acc')
plt.legend()
plt.xlim(0,num_epochs)
plt.xlabel('Epochs')

plt.ylabel('Acc')
# Out:
# Text(0, 0.5, 'Acc')

# %%
plt.figure(figsize = (8, 5))
plt.plot(lr_oneCycle,label='lr oneCycle')
plt.legend()
plt.xlim(0,num_epochs)
plt.xlabel('Epochs')

plt.ylabel('Learning rate')
# Out:
# Text(0, 0.5, 'Learning rate')

# %%
from train_basic import *
import os
import shutil
import models
from timm.models import create_model
from models.modules.mobileone import reparameterize_model
import torch
import torch.nn as nn
import torchvision
from dataset_basic import get_transforms, load_data, get_data_loaders
from label_smooth import LabelSmoothingCrossEntropy
import models

#path = './透明_by_CCD/1站'
#path = '大峰2034-07-19-NG/透明'
path = '1020_NG_膠囊_by_CCD/CCD1'
#path = 'CCD1_original_combine_foreground_in_right__rotate90_and-90'
#path = './AAA123/CCD8/Part'
#path = './透明_combine'
bs = 16  # Batch size

transformer = get_transforms()
train, val, test, original = load_data(path, transformer)
loaders = get_data_loaders(train, val, test, bs)

dataset_sizes = {
    'train': len(train),
    'val': len(val),
    'test': len(test),
}
num_epochs_unfreeze = 100

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

############################# ml-fasttvit #################################################################
# num_classes_original = len(original.classes)
# model = create_model("fastvit_t8")
# model_ft = model.to(device)
# model_ft.head = nn.Linear(in_features=model.head.in_features, out_features=num_classes_original, bias=True)

############################# END ##################################################################################

######################### ml-fastvit by another way ###########################################################
# # Assuming other necessary imports are already done
from models import fastvit_t8  # Import the model

# Initialize the model
model = fastvit_t8(pretrained=False)
model.to(device)

# Adapt the final layer if necessary (assuming a classification task)
num_classes_original = len(original.classes)
model_ft = model.to(device)
model_ft.head = nn.Linear(in_features=model.head.in_features, out_features=num_classes_original, bias=True)

# Load pretrained weights if available
# Make sure the format of your checkpoint matches what the model expects
checkpoint_path = './save_model/fastvit_t8_freeze_CCD1_without_augmentation_1219.pt'
#checkpoint = torch.load(checkpoint_path, map_location='cpu')
checkpoint = torch.load(checkpoint_path)
if 'state_dict' in checkpoint:
    model_ft.load_state_dict(checkpoint['state_dict'])
else:
    model_ft.load_state_dict(checkpoint)

#Proceed with the rest of your code for training, validation, etc.



########################### END ##########################################################################


#model_ft.load_state_dict(torch.load('./save_model/fastvit_t8_freeze_CCD1_original_combine_foreground_in_right_rotate90_and-90_1215.pt'))

for param in model_ft.parameters():
    param.requires_grad = True

model_ft = model_ft.to(device)

# Loss function
#criterion = nn.CrossEntropyLoss()
criterion = LabelSmoothingCrossEntropy(reduction='sum')

# Optimizer
optimizer_ft = AdamW(model_ft.parameters(), lr=2.31E-03, betas=(0.9, 0.99), weight_decay=0.01, amsgrad=False)
#optimizer_ft = AdamW(model_ft.parameters(), lr=6.19E-03, betas=(0.9, 0.99), weight_decay=0.01, amsgrad=False)

# Scheduler
exp_lr_scheduler = OneCycleLR(optimizer_ft, lr_range=(1.0E-04, 1.0E-02), num_steps=int(len(loaders['train'])*num_epochs_unfreeze/len(loaders['train'])))

# Train the model
train_loss_result, val_loss_result, train_acc_result, val_acc_result, lr_oneCycle, model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, loaders, dataset_sizes, num_epochs=num_epochs_unfreeze, device=device)

torch.save(model_ft.state_dict(), './save_model/fastvit_t8_unfreeze_CCD1_without_augmentation_1219.pt')
# Out:
# Epoch 0/99
# ----------
# train Loss: 8.3462 Acc: 1.0000
# val Loss: 16.5512 Acc: 0.7500
#
# Epoch 1/99
# ----------
# train Loss: 8.3152 Acc: 1.0000
# val Loss: 19.2029 Acc: 0.7500
#
# Epoch 2/99
# ----------
# train Loss: 8.2999 Acc: 1.0000
# val Loss: 19.0222 Acc: 0.7692
#
# Epoch 3/99
# ----------
# train Loss: 8.2866 Acc: 1.0000
# val Loss: 16.4856 Acc: 0.7308
#
# Epoch 4/99
# ----------
# train Loss: 8.2744 Acc: 1.0000
# val Loss: 22.6043 Acc: 0.6154
#
# Epoch 5/99
# ----------
# train Loss: 8.2709 Acc: 1.0000
# val Loss: 16.3988 Acc: 0.8077
#
# Epoch 6/99
# ----------
# train Loss: 8.2975 Acc: 1.0000
# val Loss: 37.7517 Acc: 0.4615
#
# Epoch 7/99
# ----------
# train Loss: 8.3331 Acc: 1.0000
# val Loss: 18.8012 Acc: 0.7115
#
# Epoch 8/99
# ----------
# train Loss: 8.3854 Acc: 0.9978
# val Loss: 17.9280 Acc: 0.6923
#
# Epoch 9/99
# ----------
# train Loss: 8.4434 Acc: 0.9978
# val Loss: 43.4662 Acc: 0.2692
#
# Epoch 10/99
# ----------
# train Loss: 8.5000 Acc: 0.9978
# val Loss: 53.6057 Acc: 0.3077
#
# Epoch 11/99
# ----------
# train Loss: 8.4512 Acc: 0.9978
# val Loss: 132.5922 Acc: 0.1731
#
# Epoch 12/99
# ----------
# train Loss: 8.5648 Acc: 0.9957
# val Loss: 37.9475 Acc: 0.3462
#
# Epoch 13/99
# ----------
# train Loss: 8.4644 Acc: 0.9978
# val Loss: 30.2941 Acc: 0.5385
#
# Epoch 14/99
# ----------
# train Loss: 8.4288 Acc: 0.9978
# val Loss: 102.1306 Acc: 0.1731
#
# Epoch 15/99
# ----------
# train Loss: 8.3087 Acc: 1.0000
# val Loss: 38.5690 Acc: 0.3269
#
# Epoch 16/99
# ----------
# train Loss: 8.2932 Acc: 1.0000
# val Loss: 36.5249 Acc: 0.3654
#
# Epoch 17/99
# ----------
# train Loss: 8.2734 Acc: 1.0000
# val Loss: 39.2037 Acc: 0.3462
#
# Epoch 18/99
# ----------
# train Loss: 8.2671 Acc: 1.0000
# val Loss: 23.1581 Acc: 0.7500
#
# Epoch 19/99
# ----------
# train Loss: 8.2653 Acc: 1.0000
# val Loss: 41.7116 Acc: 0.3077
#
# Epoch 20/99
# ----------
# train Loss: 8.2825 Acc: 1.0000
# val Loss: 27.7505 Acc: 0.5962
#
# Epoch 21/99
# ----------
# train Loss: 8.4652 Acc: 0.9978
# val Loss: 64.6137 Acc: 0.0962
#
# Epoch 22/99
# ----------
# train Loss: 9.7248 Acc: 0.9698
# val Loss: 43.9565 Acc: 0.0577
#
# Epoch 23/99
# ----------
# train Loss: 10.5506 Acc: 0.9483
# val Loss: 44.0876 Acc: 0.1346
#
# Epoch 24/99
# ----------
# train Loss: 9.4969 Acc: 0.9892
# val Loss: 57.8001 Acc: 0.1346
#
# Epoch 25/99
# ----------
# train Loss: 9.5542 Acc: 0.9677
# val Loss: 53.2411 Acc: 0.2308
#
# Epoch 26/99
# ----------
# train Loss: 8.7514 Acc: 0.9935
# val Loss: 57.2812 Acc: 0.0962
#
# Epoch 27/99
# ----------
# train Loss: 8.5597 Acc: 0.9978
# val Loss: 47.7375 Acc: 0.2692
#
# Epoch 28/99
# ----------
# train Loss: 9.2666 Acc: 0.9784
# val Loss: 463.5984 Acc: 0.1346
#
# Epoch 29/99
# ----------
# train Loss: 9.5913 Acc: 0.9806
# val Loss: 36.9807 Acc: 0.4038
#
# Epoch 30/99
# ----------
# train Loss: 8.7366 Acc: 0.9957
# val Loss: 27.5419 Acc: 0.5192
#
# Epoch 31/99
# ----------
# train Loss: 8.5461 Acc: 0.9978
# val Loss: 46.6840 Acc: 0.1923
#
# Epoch 32/99
# ----------
# train Loss: 8.6616 Acc: 0.9935
# val Loss: 245.9758 Acc: 0.0385
#
# Epoch 33/99
# ----------
# train Loss: 8.7453 Acc: 0.9914
# val Loss: 38.2584 Acc: 0.2885
#
# Epoch 34/99
# ----------
# train Loss: 9.2556 Acc: 0.9806
# val Loss: 49.3475 Acc: 0.3077
#
# Epoch 35/99
# ----------
# train Loss: 9.9401 Acc: 0.9698
# val Loss: 137.7677 Acc: 0.1731
#
# Epoch 36/99
# ----------
# train Loss: 9.9728 Acc: 0.9612
# val Loss: 675.8277 Acc: 0.1346
#
# Epoch 37/99
# ----------
# train Loss: 9.5542 Acc: 0.9720
# val Loss: 41.2351 Acc: 0.4615
#
# Epoch 38/99
# ----------
# train Loss: 9.9023 Acc: 0.9612
# val Loss: 68.0197 Acc: 0.1538
#
# Epoch 39/99
# ----------
# train Loss: 10.0915 Acc: 0.9634
# val Loss: 53.8639 Acc: 0.1731
#
# Epoch 40/99
# ----------
# train Loss: 10.5389 Acc: 0.9526
# val Loss: 68.6498 Acc: 0.0577
#
# Epoch 41/99
# ----------
# train Loss: 9.4758 Acc: 0.9828
# val Loss: 28.4382 Acc: 0.6538
#
# Epoch 42/99
# ----------
# train Loss: 9.3808 Acc: 0.9892
# val Loss: 538.9730 Acc: 0.0769
#
# Epoch 43/99
# ----------
# train Loss: 8.7004 Acc: 1.0000
# val Loss: 46.3814 Acc: 0.2500
#
# Epoch 44/99
# ----------
# train Loss: 9.1290 Acc: 0.9849
# val Loss: 127.1892 Acc: 0.0769
#
# Epoch 45/99
# ----------
# train Loss: 10.1901 Acc: 0.9612
# val Loss: 51.8487 Acc: 0.1346
#
# Epoch 46/99
# ----------
# train Loss: 10.5297 Acc: 0.9526
# val Loss: 65.5164 Acc: 0.0962
#
# Epoch 47/99
# ----------
# train Loss: 11.6153 Acc: 0.9310
# val Loss: 283.7749 Acc: 0.1923
#
# Epoch 48/99
# ----------
# train Loss: 9.6162 Acc: 0.9828
# val Loss: 45.5748 Acc: 0.2500
#
# Epoch 49/99
# ----------
# train Loss: 9.3692 Acc: 0.9784
# val Loss: 50.7696 Acc: 0.3654
#
# Epoch 50/99
# ----------
# train Loss: 8.9760 Acc: 0.9914
# val Loss: 39.2644 Acc: 0.3269
#
# Epoch 51/99
# ----------
# train Loss: 8.9240 Acc: 0.9935
# val Loss: 39.3307 Acc: 0.3654
#
# Epoch 52/99
# ----------
# train Loss: 8.5808 Acc: 0.9978
# val Loss: 22.7903 Acc: 0.6154
#
# Epoch 53/99
# ----------
# train Loss: 8.3833 Acc: 1.0000
# val Loss: 19.7478 Acc: 0.6731
#
# Epoch 54/99
# ----------
# train Loss: 8.3193 Acc: 1.0000
# val Loss: 32.1325 Acc: 0.4615
#
# Epoch 55/99
# ----------
# train Loss: 8.2953 Acc: 1.0000
# val Loss: 29.3037 Acc: 0.4615
#
# Epoch 56/99
# ----------
# train Loss: 8.2815 Acc: 1.0000
# val Loss: 22.8975 Acc: 0.6346
#
# Epoch 57/99
# ----------
# train Loss: 8.2697 Acc: 1.0000
# val Loss: 21.6274 Acc: 0.6731
#
# Epoch 58/99
# ----------
# train Loss: 8.2683 Acc: 1.0000
# val Loss: 19.8403 Acc: 0.6731
#
# Epoch 59/99
# ----------
# train Loss: 8.2885 Acc: 1.0000
# val Loss: 19.5525 Acc: 0.6923
#
# Epoch 60/99
# ----------
# train Loss: 8.2965 Acc: 1.0000
# val Loss: 44.7409 Acc: 0.2692
#
# Epoch 61/99
# ----------
# train Loss: 8.2744 Acc: 1.0000
# val Loss: 22.6970 Acc: 0.6538
#
# Epoch 62/99
# ----------
# train Loss: 8.2734 Acc: 1.0000
# val Loss: 30.5439 Acc: 0.5769
#
# Epoch 63/99
# ----------
# train Loss: 8.3001 Acc: 1.0000
# val Loss: 45.1910 Acc: 0.2885
#
# Epoch 64/99
# ----------
# train Loss: 9.2139 Acc: 0.9806
# val Loss: 75.6894 Acc: 0.1154
#
# Epoch 65/99
# ----------
# train Loss: 9.8544 Acc: 0.9698
# val Loss: 370.5135 Acc: 0.2115
#
# Epoch 66/99
# ----------
# train Loss: 8.9394 Acc: 0.9892
# val Loss: 41.9091 Acc: 0.3077
#
# Epoch 67/99
# ----------
# train Loss: 8.5911 Acc: 0.9935
# val Loss: 21.7809 Acc: 0.6731
#
# Epoch 68/99
# ----------
# train Loss: 8.3791 Acc: 1.0000
# val Loss: 36.9291 Acc: 0.4423
#
# Epoch 69/99
# ----------
# train Loss: 8.2950 Acc: 1.0000
# val Loss: 23.1715 Acc: 0.6538
#
# Epoch 70/99
# ----------
# train Loss: 8.2711 Acc: 1.0000
# val Loss: 23.8982 Acc: 0.6538
#
# Epoch 71/99
# ----------
# train Loss: 8.2601 Acc: 1.0000
# val Loss: 22.5037 Acc: 0.6538
#
# Epoch 72/99
# ----------
# train Loss: 8.2530 Acc: 1.0000
# val Loss: 24.7437 Acc: 0.6346
#
# Epoch 73/99
# ----------
# train Loss: 8.2495 Acc: 1.0000
# val Loss: 24.5182 Acc: 0.6346
#
# Epoch 74/99
# ----------
# train Loss: 8.2460 Acc: 1.0000
# val Loss: 22.8971 Acc: 0.6538
#
# Epoch 75/99
# ----------
# train Loss: 8.2436 Acc: 1.0000
# val Loss: 21.7686 Acc: 0.6923
#
# Epoch 76/99
# ----------
# train Loss: 8.2406 Acc: 1.0000
# val Loss: 22.0846 Acc: 0.6731
#
# Epoch 77/99
# ----------
# train Loss: 8.2400 Acc: 1.0000
# val Loss: 21.2655 Acc: 0.7308
#
# Epoch 78/99
# ----------
# train Loss: 8.2399 Acc: 1.0000
# val Loss: 20.7950 Acc: 0.7308
#
# Epoch 79/99
# ----------
# train Loss: 8.2393 Acc: 1.0000
# val Loss: 23.0317 Acc: 0.6538
#
# Epoch 80/99
# ----------
# train Loss: 8.2408 Acc: 1.0000
# val Loss: 20.6465 Acc: 0.7115
#
# Epoch 81/99
# ----------
# train Loss: 8.2412 Acc: 1.0000
# val Loss: 23.6352 Acc: 0.6538
#
# Epoch 82/99
# ----------
# train Loss: 8.2421 Acc: 1.0000
# val Loss: 21.3911 Acc: 0.7308
#
# Epoch 83/99
# ----------
# train Loss: 8.2400 Acc: 1.0000
# val Loss: 22.2365 Acc: 0.6731
#
# Epoch 84/99
# ----------
# train Loss: 8.2392 Acc: 1.0000
# val Loss: 20.6252 Acc: 0.7115
#
# Epoch 85/99
# ----------
# train Loss: 8.2372 Acc: 1.0000
# val Loss: 20.8241 Acc: 0.7115
#
# Epoch 86/99
# ----------
# train Loss: 8.2370 Acc: 1.0000
# val Loss: 20.9448 Acc: 0.7115
#
# Epoch 87/99
# ----------
# train Loss: 8.2345 Acc: 1.0000
# val Loss: 20.8276 Acc: 0.7115
#
# Epoch 88/99
# ----------
# train Loss: 8.2334 Acc: 1.0000
# val Loss: 21.0711 Acc: 0.7115
#
# Epoch 89/99
# ----------
# train Loss: 8.2317 Acc: 1.0000
# val Loss: 20.8950 Acc: 0.7115
#
# Epoch 90/99
# ----------
# train Loss: 8.2297 Acc: 1.0000
# val Loss: 20.5871 Acc: 0.7115
#
# Epoch 91/99
# ----------
# train Loss: 8.2289 Acc: 1.0000
# val Loss: 20.6055 Acc: 0.7115
#
# Epoch 92/99
# ----------
# train Loss: 8.2287 Acc: 1.0000
# val Loss: 20.5933 Acc: 0.7115
#
# Epoch 93/99
# ----------
# train Loss: 8.2286 Acc: 1.0000
# val Loss: 20.5945 Acc: 0.7115
#
# Epoch 94/99
# ----------
# train Loss: 8.2285 Acc: 1.0000
# val Loss: 20.5863 Acc: 0.7115
#
# Epoch 95/99
# ----------
# train Loss: 8.2284 Acc: 1.0000
# val Loss: 20.5976 Acc: 0.7115
#
# Epoch 96/99
# ----------
# train Loss: 8.2283 Acc: 1.0000
# val Loss: 20.6031 Acc: 0.7115
#
# Epoch 97/99
# ----------
# train Loss: 8.2283 Acc: 1.0000
# val Loss: 20.6056 Acc: 0.7115
#
# Epoch 98/99
# ----------
# train Loss: 8.2282 Acc: 1.0000
# val Loss: 20.6083 Acc: 0.7115
#
# Epoch 99/99
# ----------
# train Loss: 8.2281 Acc: 1.0000
# val Loss: 20.6228 Acc: 0.7115
#
# Training complete in 5m 5s
# Best val Acc: 0.807692
# training finish !

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 5))
plt.plot(train_loss_result,label='train loss')
plt.plot(val_loss_result, label='val loss')
plt.legend()
plt.xlim(0,num_epochs_unfreeze)
plt.xlabel('Epochs')

plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize = (8, 5))
plt.plot(train_acc_result,label='train acc')
plt.plot(val_acc_result, label='val acc')
plt.legend()
plt.xlim(0,num_epochs_unfreeze)
plt.xlabel('Epochs')

plt.ylabel('Acc')
# Out:
# Text(0, 0.5, 'Acc')

# %%
plt.figure(figsize = (8, 5))
plt.plot(lr_oneCycle,label='lr oneCycle')
plt.legend()
plt.xlim(0,num_epochs_unfreeze)
plt.xlabel('Epochs')

plt.ylabel('Learning rate')
# Out:
# Text(0, 0.5, 'Learning rate')
